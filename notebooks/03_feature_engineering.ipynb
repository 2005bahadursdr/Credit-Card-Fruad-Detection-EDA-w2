# %% [markdown]
# # Feature Engineering
# Scaling Time and Amount, and creating train/test splits using the project's source code.

# %%
import sys
import os
# Add the root directory to the sys path so we can import from src
sys.path.append(os.path.abspath('..'))

from src.data_preprocessing import load_and_preprocess_data

# %%
# Execute data preprocessing (scales features and performs train/test split)
X_train, X_test, y_train, y_test = load_and_preprocess_data(filepath='../data/raw/creditcard.csv')
# Out:
# Loading dataset...
# Scaling Time and Amount using RobustScaler...
# Splitting dataset...
# Preprocessing complete. Data saved to data/processed/

# %%
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)
# Out:
# X_train shape: (227845, 30)
# X_test shape: (56962, 30)
